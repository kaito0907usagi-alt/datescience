# %% [markdown]
# ### Python環境のテストコード
# - 以下のセルを選択し `Shift` + `Enter` キーを押下して実行してください
# - エラーメッセージが表示されなければ成功です
# - Google Colaboratory (Colab)で実行する場合は先頭行のコメントアウトを外し、japanize-matplotlibをインストールしてください

# %%
# !pip install opencv-python matplotlib numpy pandas pyserial requests japanize-matplotlib scikit-learn setuptools pygame PyOpenGL pyqtgraph PyQt5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
from scipy import stats
# %matplotlib inline

x = np.arange(0, 2.0*np.pi, 0.2)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x    , y, "ko-",  linewidth=1, label="ko-")
ax.plot(x+0.5, y, "r^--", linewidth=1, label="r^--")
ax.plot(x+1.0, y, "bx:",  linewidth=1, label="bx:")
ax.plot(x+1.5, y, "gs-.", linewidth=1, label="gs-.")
ax.plot(x+2.0, y, "yd-",  linewidth=1, label="yd-.")
ax.set_xlim(0, 2.0*np.pi+2.0)
ax.set_ylim(-1.2, 1.2)
ax.tick_params(labelsize=16)
ax.legend()

z_values = np.arange(-3.0, 3.1, 0.1)
cdf_values = stats.norm.cdf(z_values)
ax.set_xlabel("$X$", fontsize=20, labelpad=8, math_fontfamily='cm')
ax.set_ylabel("$y$", fontsize=20, labelpad=8, math_fontfamily='cm')

pd.DataFrame({'z': z_values, '下側確率': cdf_values})
